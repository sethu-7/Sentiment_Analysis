# %% [markdown]
# <a href="https://colab.research.google.com/github/sethu-7/Sentimental_Analysis/blob/main/Embeddingstry.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import tensorflow as tf

# %%
# Check for GPU availability
print("GPU", "available (Yess!!)" if tf.config.list_physical_devices("GPU") else "not available")
# Out:
# GPU available (Yess!!)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data=pd.read_csv("/content/drive/MyDrive/amazon_reviews_us_Books_v1_02.tsv",sep='\t',on_bad_lines='skip')
data.head()
# Out:
#   marketplace  customer_id       review_id  product_id  product_parent  \
# 0          US     12076615   RQ58W7SMO911M  0385730586       122662979
# 1          US     12703090    RF6IUKMGL8SF  0811828964        56191234
# 2          US     12257412  R1DOSHH6AI622S  1844161560       253182049
# 3          US     50732546   RATOTLA3OF70O  0373836635       348672532
# 4          US     51964897  R1TNWRKIVHVYOV  0262181533       598678717
#
#                                        product_title product_category  \
# 0         Sisterhood of the Traveling Pants (Book 1)            Books
# 1      The Bad Girl's Guide to Getting What You Want            Books
# 2             Eisenhorn (A Warhammer 40,000 Omnibus)            Books
# 3                    Colby Conspiracy (Colby Agency)            Books
# 4  The Psychology of Proof: Deductive Reasoning i...            Books
#
#    star_rating  helpful_votes  total_votes vine verified_purchase  \
# 0          4.0            2.0          3.0    N                 N
# 1          3.0            5.0          5.0    N                 N
# 2          4.0            1.0         22.0    N                 N
# 3          5.0            2.0          2.0    N                 N
# 4          4.0            0.0          2.0    N                 N
#
#                          review_headline  \
# 0  this book was a great learning novel!
# 1                              Fun Fluff
# 2                    this isn't a review
# 3              fine author on her A-game
# 4          Execellent cursor examination
#
#                                          review_body review_date
# 0  this boook was a great one that you could lear...  2005-10-14
# 1  If you are looking for something to stimulate ...  2005-10-14
# 2  never read it-a young relative idicated he lik...  2005-10-14
# 3  Though she is honored to be Chicago Woman of t...  2005-10-14
# 4  Review based on a cursory examination by Unive...  2005-10-14

# %%
column_to_drop = 'verified_purchase'
matching_columns = [col for col in data.columns if col.strip().lower() == column_to_drop.strip().lower()]

if len(matching_columns) == 0:
    print(f"Column '{column_to_drop}' not found in the DataFrame.")
else:
    # Drop the column(s) with matching names
    data.drop(columns=matching_columns, inplace=True)
    print("Column(s) dropped successfully.")

# Display the first few rows of the modified DataFrame
print(data.head())
# Out:
# Column(s) dropped successfully.
#   marketplace  customer_id       review_id  product_id  product_parent  \
# 0          US     12076615   RQ58W7SMO911M  0385730586       122662979
# 1          US     12703090    RF6IUKMGL8SF  0811828964        56191234
# 2          US     12257412  R1DOSHH6AI622S  1844161560       253182049
# 3          US     50732546   RATOTLA3OF70O  0373836635       348672532
# 4          US     51964897  R1TNWRKIVHVYOV  0262181533       598678717
#
#                                        product_title product_category  \
# 0         Sisterhood of the Traveling Pants (Book 1)            Books
# 1      The Bad Girl's Guide to Getting What You Want            Books
# 2             Eisenhorn (A Warhammer 40,000 Omnibus)            Books
# 3                    Colby Conspiracy (Colby Agency)            Books
# 4  The Psychology of Proof: Deductive Reasoning i...            Books
#
#    star_rating  helpful_votes  total_votes vine  \
# 0          4.0            2.0          3.0    N
# 1          3.0            5.0          5.0    N
# 2          4.0            1.0         22.0    N
# 3          5.0            2.0          2.0    N
# 4          4.0            0.0          2.0    N
#
#                          review_headline  \
# 0  this book was a great learning novel!
# 1                              Fun Fluff
# 2                    this isn't a review
# 3              fine author on her A-game
# 4          Execellent cursor examination
#
#                                          review_body review_date
# 0  this boook was a great one that you could lear...  2005-10-14
# 1  If you are looking for something to stimulate ...  2005-10-14
# 2  never read it-a young relative idicated he lik...  2005-10-14
# 3  Though she is honored to be Chicago Woman of t...  2005-10-14
# 4  Review based on a cursory examination by Unive...  2005-10-14

# %%
data.head()
# Out:
#   marketplace  customer_id       review_id  product_id  product_parent  \
# 0          US     12076615   RQ58W7SMO911M  0385730586       122662979
# 1          US     12703090    RF6IUKMGL8SF  0811828964        56191234
# 2          US     12257412  R1DOSHH6AI622S  1844161560       253182049
# 3          US     50732546   RATOTLA3OF70O  0373836635       348672532
# 4          US     51964897  R1TNWRKIVHVYOV  0262181533       598678717
#
#                                        product_title product_category  \
# 0         Sisterhood of the Traveling Pants (Book 1)            Books
# 1      The Bad Girl's Guide to Getting What You Want            Books
# 2             Eisenhorn (A Warhammer 40,000 Omnibus)            Books
# 3                    Colby Conspiracy (Colby Agency)            Books
# 4  The Psychology of Proof: Deductive Reasoning i...            Books
#
#    star_rating  helpful_votes  total_votes vine  \
# 0          4.0            2.0          3.0    N
# 1          3.0            5.0          5.0    N
# 2          4.0            1.0         22.0    N
# 3          5.0            2.0          2.0    N
# 4          4.0            0.0          2.0    N
#
#                          review_headline  \
# 0  this book was a great learning novel!
# 1                              Fun Fluff
# 2                    this isn't a review
# 3              fine author on her A-game
# 4          Execellent cursor examination
#
#                                          review_body review_date
# 0  this boook was a great one that you could lear...  2005-10-14
# 1  If you are looking for something to stimulate ...  2005-10-14
# 2  never read it-a young relative idicated he lik...  2005-10-14
# 3  Though she is honored to be Chicago Woman of t...  2005-10-14
# 4  Review based on a cursory examination by Unive...  2005-10-14

# %%
data.dropna(subset=['review_body'], inplace=True)

# %%
# Define a function to map star ratings to sentiment categories
def map_rating_to_sentiment(rating):
    if rating >= 4.0:
        return 'positive'
    elif rating <= 2.0:
        return 'negative'
    else:
        return 'neutral'

# Apply the mapping function to create the 'sentiment' column
data['sentiment'] = data['star_rating'].apply(map_rating_to_sentiment)

# Now 'data' DataFrame contains the 'sentiment' column based on the mapping of 'star_rating'
print(data)
# Out:
#         marketplace  customer_id       review_id  product_id  product_parent  \
# 0                US     12076615   RQ58W7SMO911M  0385730586       122662979
# 1                US     12703090    RF6IUKMGL8SF  0811828964        56191234
# 2                US     12257412  R1DOSHH6AI622S  1844161560       253182049
# 3                US     50732546   RATOTLA3OF70O  0373836635       348672532
# 4                US     51964897  R1TNWRKIVHVYOV  0262181533       598678717
# ...             ...          ...             ...         ...             ...
# 3105365          US     53096582  R1U2RAML67OKWM  0471114251       574261099
# 3105366          US     53011769  R33HOJ2OWJIDQI  089145537X       836948045
# 3105367          US     53096573   RPLV77JZXG575  047194128X       377091465
# 3105368          US     53096571   RHL4UW17ZK72A  0521314925       980601331
# 3105369          US     53096571  R34N4QWDXX58WB  0870210092       442607382
#
#                                              product_title product_category  \
# 0               Sisterhood of the Traveling Pants (Book 1)            Books
# 1            The Bad Girl's Guide to Getting What You Want            Books
# 2                   Eisenhorn (A Warhammer 40,000 Omnibus)            Books
# 3                          Colby Conspiracy (Colby Agency)            Books
# 4        The Psychology of Proof: Deductive Reasoning i...            Books
# ...                                                    ...              ...
# 3105365  Bitter Winds: A Memoir of My Years in China's ...            Books
# 3105366  The Collector's Guide to Harker Pottery U.S.A....            Books
# 3105367                       Object-Oriented Type Systems            Books
# 3105368  Invention and Evolution:Design in Nature and E...            Books
# 3105369  Arming and Fitting of English Ships of War, 16...            Books
#
#          star_rating  helpful_votes  total_votes vine  \
# 0                4.0            2.0          3.0    N
# 1                3.0            5.0          5.0    N
# 2                4.0            1.0         22.0    N
# 3                5.0            2.0          2.0    N
# 4                4.0            0.0          2.0    N
# ...              ...            ...          ...  ...
# 3105365          4.0            9.0          9.0    N
# 3105366          5.0           27.0         27.0    N
# 3105367          4.0            4.0          4.0    N
# 3105368          5.0            9.0          9.0    N
# 3105369          4.0           12.0         13.0    N
#
#                                           review_headline  \
# 0                   this book was a great learning novel!
# 1                                               Fun Fluff
# 2                                     this isn't a review
# 3                               fine author on her A-game
# 4                           Execellent cursor examination
# ...                                                   ...
# 3105365  Harry Wu could have taught Kafka a thing or two.
# 3105366           The definitive volume on Harker Pottery
# 3105367                    Good techniques, well written.
# 3105368                                    BUY THIS BOOK!
# 3105369      good enough to understand all of Pat O'brien
#
#                                                review_body review_date  \
# 0        this boook was a great one that you could lear...  2005-10-14
# 1        If you are looking for something to stimulate ...  2005-10-14
# 2        never read it-a young relative idicated he lik...  2005-10-14
# 3        Though she is honored to be Chicago Woman of t...  2005-10-14
# 4        Review based on a cursory examination by Unive...  2005-10-14
# ...                                                    ...         ...
# 3105365  &quot;Bitter Winds&quot; is at once fascinatin...  1995-07-19
# 3105366  OK, I'm biased. My mother wrote this one. Many...  1995-07-18
# 3105367  The best (and possibly only) book I've seen on...  1995-07-07
# 3105368  This is a beautiful book.  French talks about ...  1995-06-24
# 3105369  Nice diags, lucid explanations of rigging, gun...  1995-06-24
#
#         sentiment
# 0        positive
# 1         neutral
# 2        positive
# 3        positive
# 4        positive
# ...           ...
# 3105365  positive
# 3105366  positive
# 3105367  positive
# 3105368  positive
# 3105369  positive
#
# [3105366 rows x 15 columns]

# %%
X = data['review_body']
y = data['sentiment']

# %%
# Manually split the data into training and testing sets
# Let's say you want to split 80% for training and 20% for testing
train_data = data.sample(frac=0.8, random_state=42)  # 80% of the data for training
test_data = data.drop(train_data.index)  # Remaining 20% for testing

# Define input features (X) and target variable (y) for training and testing
X_train = train_data['review_body']
y_train = train_data['sentiment']
X_test = test_data['review_body']
y_test = test_data['sentiment']

# Now you can proceed with further preprocessing and model building using X_train, y_train, X_test, and y_test.
